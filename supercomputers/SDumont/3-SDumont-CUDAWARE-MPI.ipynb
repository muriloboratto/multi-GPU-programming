# %% [markdown]
# # CUDAWARE-MPI on Multi-GPU

# %% [markdown]
# In this notebook we will introduce how MPI and CUDA compatibility works, how efficient it is, and how it can be used on API CUDAWARE-MPI.

# %% [markdown]
# ## Objectives

# %% [markdown]
# By the time you complete this notebook you will:

# %% [markdown]
# - Understand the concepts of MPI, CUDA and CUDAWARE-MPI on multiple GPUs.
# - Understant the API CUDAWARE-MPI.

# %% [markdown]
# ## Benchmarks Ping-Pong

# %% [markdown]
# In this notebook, we will look at a simple *ping pong* code that measures the bandwidth for data transfers between 2 MPI processes. We will look at the following versions:
#
# - A first version using CPU with __MPI__;
# - A second version with __MPI + CUDA__ between two GPUs which processes data through CPU memory;
# - And the last one that uses __CUDAWARE-MPI__ which exchange data directly between GPUs using GPUdirect or by NVLINK.

# %% [markdown]
# ### MPI

# %% [markdown]
# We will start by looking at a CPU-only version of the code to understand the idea behind a simple data transfer program (*ping-pong*). MPI processes pass data back and forth, and bandwidth is calculated by measuring the data transfers, as you know how much size is being transferred. Let is look at the `ping-pong-MPI.c` code to see how it is implemented. At the top of the main program, we start the MPI, determine the total number of processes and the rank identifiers, and make sure we only have two ranks in total to run the *ping-pong*:

# %% [markdown]
# ```cpp
#     int size, rank;
#     MPI_Init(&argc, &argv);
#     MPI_Comm_size(MPI_COMM_WORLD, &size);
#     MPI_Comm_rank(MPI_COMM_WORLD, &rank);
#     MPI_Status status;
# ```

# %% [markdown]
# We then enter the main *loop* `for`, where each iteration performs data transfers and bandwidth calculations for different message size, ranging from 8 bytes to 1 GB:

# %% [markdown]
# ```cpp
#    for(int i = 0; i <= 27; i++)
#      long int N = 1 << i;
# ```

# %% [markdown]
# Next, we initialize the *A* array, define some labels to match the MPI send/receive pairs.

# %% [markdown]
# ```cpp
#    double *A = (double*) calloc (N, sizeof(double));
# ```

# %% [markdown]
# Basically, each iteration of the *loop* does the following:
#
# - If rank is 0, it first sends a message with data from the matrix \verb+A+ to rank 1, then expects to receive a message of rank 1.
#
# - If rank is 1, first expect to receive a message from rank 0 and then send a message back to rank 0.

# %% [markdown]
# ```cpp
#     start_time = MPI_Wtime();
#     for(int i = 1; i <= loop_count; i++)
#     {
#       if(rank == 0)
#       {
#         MPI_Send(A, N, MPI_DOUBLE, 1, tag1, MPI_COMM_WORLD);
#         MPI_Recv(A, N, MPI_DOUBLE, 1, tag2, MPI_COMM_WORLD, &stat);
#       }else if(rank == 1)
#        {
#          MPI_Recv(A, N, MPI_DOUBLE, 0, tag1, MPI_COMM_WORLD, &stat);
#          MPI_Send(A, N, MPI_DOUBLE, 0, tag2, MPI_COMM_WORLD);
#        }
#     }
#     stop_time = MPI_Wtime();
# ```

# %% [markdown]
# The previous two points describe an application data transfer *ping-pong*. Now that we are familiar with the basic *ping-pong* code in MPI let us look at a version that includes GPUs with CUDA. In this example, we are still passing data back and forth between two MPI ratings, but the data is in GPU memory this time. More specifically, rank 0 has a memory buffer on GPU 0, and rank 1 has a memory buffer on GPU 1, and they will pass the data between the memories of the two GPUs. Here, to get data from memory from GPU 0 to GPU 1, we will first put the data into CPU memory *host*. Next, we can see the differences between the previous version to the new version with MPI+CUDA. Then, from the synchronization results and the known size of the data transfers, we calculate the bandwidth and print the results:

# %% [markdown]
# ```cpp
# long int num_B = 8 * N;
# long int B_in_GB = 1 << 30;
# double num_GB = (double)num_B / (double)B_in_GB;
# double avg_time_per_transfer=elapsed_time/(2.0*(double)loop_count);
# ```

# %% [markdown]
# Remember that in order to compile MPI programs, we must include the appropriate compilation option, such as:

# %%
# %%writefile ping-pong-MPI.c
# #include <stdio.h>
# #include <stdlib.h>
# #include <unistd.h>
# #include <mpi.h>
#
# int main(int argc, char *argv[])
# {
#     int size, rank;
#
#     MPI_Init(&argc, &argv);
#     MPI_Comm_size(MPI_COMM_WORLD, &size);
#     MPI_Comm_rank(MPI_COMM_WORLD, &rank);
#
#     MPI_Status status;
#
#     double start_time, stop_time, elapsed_time;
#
#     for(int i = 0; i <= 27; i++)
#     {
#        long int N = 1 << i; /*Loop from 8 Bytes to 1 GB*/
#
#        double *A = (double*)calloc( N, sizeof(double));  /*Allocate memory for A on CPU*/
#
#        int tag1 = 1000;
#        int tag2 = 2000;
#
#        int loop_count = 50;
#
#        /********************************/
#        /**/ start_time = MPI_Wtime();/**/
#        /********************************/
#
#        for(int i = 1; i <= loop_count; i++)
#        {
#             if(rank == 0)
#             {
#                MPI_Send(A, N, MPI_DOUBLE, 1, tag1, MPI_COMM_WORLD);
#                MPI_Recv(A, N, MPI_DOUBLE, 1, tag2, MPI_COMM_WORLD, &status);
#             }
#             else if(rank == 1)
#             {
#                MPI_Recv(A, N, MPI_DOUBLE, 0, tag1, MPI_COMM_WORLD, &status);
#                MPI_Send(A, N, MPI_DOUBLE, 0, tag2, MPI_COMM_WORLD);
#             }
#         }
#
#        /*********************************/
#        /**/  stop_time = MPI_Wtime(); /**/
#        /********************************/
#
#         /*measured time*/
#         elapsed_time = stop_time - start_time;
#         long int num_B = 8 * N;
#         long int B_in_GB = 1 << 30;
#         double num_GB = (double)num_B / (double)B_in_GB;
#         double avg_time_per_transfer = elapsed_time / (2.0*(double)loop_count);
#
#         if(rank == 0)
#             printf("Transfer size (Bytes): %10li, Transfer Time (seconds): %15.9f, Bandwidth (GB/s): %15.9f\n",
#                    num_B, avg_time_per_transfer, num_GB/avg_time_per_transfer );
#
#         free(A);
#     }
#
#     MPI_Finalize();
#
#     return 0;
# }
# Out:
# Overwriting ping-pong-MPI.c

# %% [markdown]
# #### Run the Code

# %% [markdown]
# ##### Compile with Shell Script

# %%
# %%writefile howtocompile-MPI.sh
# #!/bin/bash
#
# usage()
# {
#  echo "howtocompile.sh: wrong number of input parameters. Exiting."
#  echo -e "Usage: bash howtocompile.sh <supercomputer>"
#  echo -e "  g.e: bash howtocompile.sh sdumont"
# }
#
# sdumont()
# {
#  mpicc ping-pong-MPI.c -o ping-pong-MPI $CPPFLAGS $LDFLAGS
# }
#
# #args in comand line
# if [ "$#" ==  0 ]; then
#  usage
#  exit
# fi
#
# #sdumont
# if [[ $1 == "sdumont" ]];then
#  sdumont
# fi
# Out:
# Writing howtocompile-MPI.sh

# %%
# !bash howtocompile-MPI.sh sdumont

# %% [markdown]
# ##### Execute with Shell Script

# %%
# %%writefile howtoexecute-MPI.sh
# #!/bin/bash
#
# usage()
# {
#  echo "howtoexecute.sh: wrong number of input parameters. Exiting."
#  echo -e "Usage: bash howtoexecute.sh <supercomputer>"
#  echo -e "  g.e: bash howtoexecute.sh sdumont"
# }
#
# sdumont()
# {
#  mpirun -np 2 --oversubscribe --report-bindings --map-by numa -x UCX_MEMTYPE_CACHE=n -mca pml ucx -mca btl ^vader,tcp,openib,smcuda -x UCX_NET_DEVICES=mlx4_0:1 ./ping-pong-MPI
# }
#
# #args in comand line
# if [ "$#" ==  0 ]; then
#  usage
#  exit
# fi
#
# #sdumont
# if [[ $1 == "sdumont" ]];then
#  sdumont
# fi
# Out:
# Writing howtoexecute-MPI.sh

# %%
# !bash howtoexecute-MPI.sh sdumont
# Out:
# [sdumont8046:35095] MCW rank 1 is not bound (or bound to all available processors)
# [sdumont8046:35094] MCW rank 0 is not bound (or bound to all available processors)
# [1765220167.430440] [sdumont8046:35095:0]     ucp_context.c:1234 UCX  WARN  network device 'mlx4_0:1' is not available, please use one or more of: 'enp61s0f0'(tcp), 'ib0'(tcp), 'lo'(tcp), 'mlx5_0:1'(ib), 'mlx5_1:1'(ib)
# [1765220167.444294] [sdumont8046:35094:0]     ucp_context.c:1234 UCX  WARN  network device 'mlx4_0:1' is not available, please use one or more of: 'enp61s0f0'(tcp), 'ib0'(tcp), 'lo'(tcp), 'mlx5_0:1'(ib), 'mlx5_1:1'(ib)
# Transfer size (Bytes):          8, Transfer Time (seconds):     0.000000923, Bandwidth (GB/s):     0.008075372
# Transfer size (Bytes):         16, Transfer Time (seconds):     0.000000287, Bandwidth (GB/s):     0.051858987
# Transfer size (Bytes):         32, Transfer Time (seconds):     0.000000333, Bandwidth (GB/s):     0.089445429
# Transfer size (Bytes):         64, Transfer Time (seconds):     0.000000366, Bandwidth (GB/s):     0.162654236
# Transfer size (Bytes):        128, Transfer Time (seconds):     0.000001747, Bandwidth (GB/s):     0.068240477
# Transfer size (Bytes):        256, Transfer Time (seconds):     0.000001654, Bandwidth (GB/s):     0.144185018
# Transfer size (Bytes):        512, Transfer Time (seconds):     0.000001831, Bandwidth (GB/s):     0.260380361
# Transfer size (Bytes):       1024, Transfer Time (seconds):     0.000002337, Bandwidth (GB/s):     0.408022178
# Transfer size (Bytes):       2048, Transfer Time (seconds):     0.000003507, Bandwidth (GB/s):     0.543833348
# Transfer size (Bytes):       4096, Transfer Time (seconds):     0.000004526, Bandwidth (GB/s):     0.842918977
# Transfer size (Bytes):       8192, Transfer Time (seconds):     0.000005305, Bandwidth (GB/s):     1.438195032
# Transfer size (Bytes):      16384, Transfer Time (seconds):     0.000007473, Bandwidth (GB/s):     2.041784852
# Transfer size (Bytes):      32768, Transfer Time (seconds):     0.000006506, Bandwidth (GB/s):     4.690473085
# Transfer size (Bytes):      65536, Transfer Time (seconds):     0.000008095, Bandwidth (GB/s):     7.540054313
# Transfer size (Bytes):     131072, Transfer Time (seconds):     0.000014915, Bandwidth (GB/s):     8.184459456
# Transfer size (Bytes):     262144, Transfer Time (seconds):     0.000029965, Bandwidth (GB/s):     8.147507248
# Transfer size (Bytes):     524288, Transfer Time (seconds):     0.000056925, Bandwidth (GB/s):     8.577661738
# Transfer size (Bytes):    1048576, Transfer Time (seconds):     0.000112386, Bandwidth (GB/s):     8.689346857
# Transfer size (Bytes):    2097152, Transfer Time (seconds):     0.000214301, Bandwidth (GB/s):     9.113951919
# Transfer size (Bytes):    4194304, Transfer Time (seconds):     0.000418429, Bandwidth (GB/s):     9.335521647
# Transfer size (Bytes):    8388608, Transfer Time (seconds):     0.000822790, Bandwidth (GB/s):     9.495132992
# Transfer size (Bytes):   16777216, Transfer Time (seconds):     0.001787345, Bandwidth (GB/s):     8.742016301
# Transfer size (Bytes):   33554432, Transfer Time (seconds):     0.005543378, Bandwidth (GB/s):     5.637356607
# Transfer size (Bytes):   67108864, Transfer Time (seconds):     0.015629680, Bandwidth (GB/s):     3.998802317
# Transfer size (Bytes):  134217728, Transfer Time (seconds):     0.025696175, Bandwidth (GB/s):     4.864537317
# Transfer size (Bytes):  268435456, Transfer Time (seconds):     0.051652404, Bandwidth (GB/s):     4.840045824
# Transfer size (Bytes):  536870912, Transfer Time (seconds):     0.103413658, Bandwidth (GB/s):     4.834951282
# Transfer size (Bytes): 1073741824, Transfer Time (seconds):     0.205141004, Bandwidth (GB/s):     4.874695855

# %% [markdown]
# ### MPI + CUDA

# %% [markdown]
# Now that we are familiar with the basic *ping-pong* code in MPI let us look at a version that includes GPUs with CUDA. In this example, we are still passing data back and forth between two MPI ratings, but the data is in GPU memory this time. More specifically, rank 0 has a memory buffer on GPU 0, and rank 1 has a memory buffer on GPU 1, and they will pass the data between the memories of the two GPUs. Here, to get data from memory from GPU 0 to GPU 1, we will first put the data into CPU memory *host*. Next, we can see the differences between the previous version to the new version with MPI+CUDA.

# %% [markdown]
# ```cpp
#  start_time = MPI_Wtime();
#  for(int i = 1; i <= loop_count; i++)
#  {
#   if(rank == 0)
#   {
#    cudaMemcpy(A, d_A, N * sizeof(double), cudaMemcpyDeviceToHost);
#    MPI_Send(A, N, MPI_DOUBLE, 1, tag1, MPI_COMM_WORLD);
#    MPI_Recv(A, N, MPI_DOUBLE, 1, tag2, MPI_COMM_WORLD, &status);
#    cudaMemcpy(d_A, A, N * sizeof(double), cudaMemcpyHostToDevice);
#    }else if(rank == 1)
#     {
#      MPI_Recv(A, N, MPI_DOUBLE, 0, tag1, MPI_COMM_WORLD, &status);
#      cudaMemcpy(d_A, A, N * sizeof(double), cudaMemcpyHostToDevice);
#      cudaMemcpy(A, d_A, N * sizeof(double), cudaMemcpyDeviceToHost);
#      MPI_Send(A, N, MPI_DOUBLE, 0, tag2, MPI_COMM_WORLD);
#     }
#  }
#  stop_time = MPI_Wtime();
# ```

# %% [markdown]
# Similar to the CPU-only version, we initialize MPI and find the identifier of each MPI rank, but here we also assign each rank a different GPU (i.e., rank 0 is assigned to GPU 0 and rank 1 is mapped to GPU 1).

# %% [markdown]
# ```cpp
# int size, rank;
# MPI_Init(&argc, &argv);
# MPI_Comm_size(MPI_COMM_WORLD, &size);
# MPI_Comm_rank(MPI_COMM_WORLD, &rank);
# MPI_Status status;
#
# cudaSetDevice(rank);
# ```

# %% [markdown]
# For this release, each iteration of the \emph{loop} does the following:
#
# - We enter the main *loop* `for`, which iterates over the different message sizes, and assign and initialize the __A__ array. However, we now have a call to `cudaMalloc` to reserve a memory buffer __d_A__ on the GPUs and a call to `cudaMemcpy` to transfer the data initialized in the *A* array to the buffer __d_A__. We need the command `cudaMemcpy` to get the data to the GPU before we start our *ping-pong*.
#
# - Data must first be transferred from GPU memory 0 to CPU memory. Then an MPI call is used to pass the data from ranks 0 to 1. Now that rank 1 has the data (in CPU memory), it can transfer it to GPU memory 1. Rank 0 must first transfer the data from a buffer in GPU 0 memory to one in CPU memory. Now that rank 1 contains the data in the CPU memory buffer, and it can transfer it to GPU 1 memory.
#
# As in the case where only the CPU is used, from the synchronization results and the known size of the data transfers, we calculate the bandwidth, print the results, and finally free up the memory of the computational resources. We ended the MPI and the program.

# %%
# %%writefile ping-pong-MPI+CUDA.cu
# #include <stdio.h>
# #include <stdlib.h>
# #include <cuda.h>
# #include <unistd.h>
# #include <mpi.h>
#
# int main(int argc, char *argv[])
# {
#     int size, rank;
#
#     MPI_Init(&argc, &argv);
#     MPI_Comm_size(MPI_COMM_WORLD, &size);
#     MPI_Comm_rank(MPI_COMM_WORLD, &rank);
#
#     MPI_Status status;
#
#     cudaSetDevice(rank);
#
#     double start_time, stop_time, elapsed_time;
#
#     for(int i = 0; i <= 27; i++)
#     {
#         long int N = 1 << i; /*Loop from 8 Bytes to 1 GB*/
#
#         double *A = (double*)calloc(N, sizeof(double)); /*Allocate memory for A on CPU*/
#
#         double *d_A;
#
#         cudaMalloc(&d_A, N * sizeof(double)) ;
#         cudaMemcpy(d_A, A, N * sizeof(double), cudaMemcpyHostToDevice);
#
#         int tag1 = 1000;
#         int tag2 = 2000;
#
#         int loop_count = 50;
#
#        /********************************/
#        /**/ start_time = MPI_Wtime();/**/
#        /********************************/
#
#         for(int i = 1; i <= loop_count; i++)
#         {
#             if(rank == 0)
#             {
#                 cudaMemcpy(A, d_A, N * sizeof(double), cudaMemcpyDeviceToHost);
#                 MPI_Send(A, N, MPI_DOUBLE, 1, tag1, MPI_COMM_WORLD);
#                 MPI_Recv(A, N, MPI_DOUBLE, 1, tag2, MPI_COMM_WORLD, &status);
#                 cudaMemcpy(d_A, A, N * sizeof(double), cudaMemcpyHostToDevice);
#             }
#             else if(rank == 1)
#             {
#                 MPI_Recv(A, N, MPI_DOUBLE, 0, tag1, MPI_COMM_WORLD, &status);
#                 cudaMemcpy(d_A, A, N * sizeof(double), cudaMemcpyHostToDevice);
#                 cudaMemcpy(A, d_A, N * sizeof(double), cudaMemcpyDeviceToHost);
#                 MPI_Send(A, N, MPI_DOUBLE, 0, tag2, MPI_COMM_WORLD);
#             }
#         }
#
#        /**********************************/
#        /**/  stop_time = MPI_Wtime(); /**/
#        /*********************************/
#
#         /*measured time*/
#         elapsed_time = stop_time - start_time;
#         long int num_B = 8 * N;
#         long int B_in_GB = 1 << 30;
#         double num_GB = (double)num_B / (double)B_in_GB;
#         double avg_time_per_transfer = elapsed_time / (2.0*(double)loop_count);
#
#         if(rank == 0)
#           printf("Transfer size (Bytes): %10li, Transfer Time (seconds): %15.9f, Bandwidth (GB/s): %15.9f\n",
#                     num_B, avg_time_per_transfer, num_GB/avg_time_per_transfer );
#
#         cudaFree(d_A);
#         free(A);
#     }
#
#     MPI_Finalize();
#
#     return 0;
# }
# Out:
# Overwriting ping-pong-MPI+CUDA.cu

# %% [markdown]
# #### Run the Code

# %% [markdown]
# ##### Compile with Shell Script

# %%
# %%writefile howtocompile-MPI+CUDA.sh
# #!/bin/bash
#
# usage()
# {
#  echo "howtocompile.sh: wrong number of input parameters. Exiting."
#  echo -e "Usage: bash howtocompile.sh <supercomputer>"
#  echo -e "  g.e: bash howtocompile.sh sdumont"
# }
#
# sdumont()
# {
#  nvcc $CPPFLAGS $LDFLAGS -lmpi ping-pong-MPI+CUDA.cu -o ping-pong-MPI+CUDA
# }
#
# #args in comand line
# if [ "$#" ==  0 ]; then
#  usage
#  exit
# fi
#
# #sdumont
# if [[ $1 == "sdumont" ]];then
#  sdumont
# fi
# Out:
# Writing howtocompile-MPI+CUDA.sh

# %%
# !bash howtocompile-MPI+CUDA.sh sdumont

# %% [markdown]
# ##### Execute with Shell Script

# %%
# %%writefile howtoexecute-MPI+CUDA.sh
# #!/bin/bash
#
# usage()
# {
#  echo "howtoexecute.sh: wrong number of input parameters. Exiting."
#  echo -e "Usage: bash howtoexecute.sh <supercomputer>"
#  echo -e "  g.e: bash howtoexecute.sh sdumont"
# }
#
# sdumont()
# {
#  mpirun -np 2 --oversubscribe --report-bindings --map-by numa -x UCX_MEMTYPE_CACHE=n -mca pml ucx -mca btl ^vader,tcp,openib,smcuda -x UCX_NET_DEVICES=mlx4_0:1 ./ping-pong-MPI+CUDA
# }
#
# #args in comand line
# if [ "$#" ==  0 ]; then
#  usage
#  exit
# fi
#
# #sdumont
# if [[ $1 == "sdumont" ]];then
#  sdumont
# fi
# Out:
# Writing howtoexecute-MPI+CUDA.sh

# %%
# !bash howtoexecute-MPI+CUDA.sh sdumont
# Out:
# [sdumont8046:35520] MCW rank 0 is not bound (or bound to all available processors)
# [sdumont8046:35521] MCW rank 1 is not bound (or bound to all available processors)
# [1765220488.946229] [sdumont8046:35521:0]     ucp_context.c:1234 UCX  WARN  network device 'mlx4_0:1' is not available, please use one or more of: 'enp61s0f0'(tcp), 'ib0'(tcp), 'lo'(tcp), 'mlx5_0:1'(ib), 'mlx5_1:1'(ib)
# [1765220488.949487] [sdumont8046:35520:0]     ucp_context.c:1234 UCX  WARN  network device 'mlx4_0:1' is not available, please use one or more of: 'enp61s0f0'(tcp), 'ib0'(tcp), 'lo'(tcp), 'mlx5_0:1'(ib), 'mlx5_1:1'(ib)
# Transfer size (Bytes):          8, Transfer Time (seconds):     0.000015677, Bandwidth (GB/s):     0.000475263
# Transfer size (Bytes):         16, Transfer Time (seconds):     0.000014940, Bandwidth (GB/s):     0.000997410
# Transfer size (Bytes):         32, Transfer Time (seconds):     0.000015152, Bandwidth (GB/s):     0.001966942
# Transfer size (Bytes):         64, Transfer Time (seconds):     0.000014967, Bandwidth (GB/s):     0.003982420
# Transfer size (Bytes):        128, Transfer Time (seconds):     0.000016628, Bandwidth (GB/s):     0.007169211
# Transfer size (Bytes):        256, Transfer Time (seconds):     0.000016523, Bandwidth (GB/s):     0.014429139
# Transfer size (Bytes):        512, Transfer Time (seconds):     0.000016767, Bandwidth (GB/s):     0.028438586
# Transfer size (Bytes):       1024, Transfer Time (seconds):     0.000017752, Bandwidth (GB/s):     0.053721260
# Transfer size (Bytes):       2048, Transfer Time (seconds):     0.000019117, Bandwidth (GB/s):     0.099774000
# Transfer size (Bytes):       4096, Transfer Time (seconds):     0.000021614, Bandwidth (GB/s):     0.176490329
# Transfer size (Bytes):       8192, Transfer Time (seconds):     0.000024768, Bandwidth (GB/s):     0.308033967
# Transfer size (Bytes):      16384, Transfer Time (seconds):     0.000034004, Bandwidth (GB/s):     0.448739608
# Transfer size (Bytes):      32768, Transfer Time (seconds):     0.000049173, Bandwidth (GB/s):     0.620621483
# Transfer size (Bytes):      65536, Transfer Time (seconds):     0.000067087, Bandwidth (GB/s):     0.909788534
# Transfer size (Bytes):     131072, Transfer Time (seconds):     0.000110267, Bandwidth (GB/s):     1.107046331
# Transfer size (Bytes):     262144, Transfer Time (seconds):     0.000202592, Bandwidth (GB/s):     1.205085696
# Transfer size (Bytes):     524288, Transfer Time (seconds):     0.000377127, Bandwidth (GB/s):     1.294739845
# Transfer size (Bytes):    1048576, Transfer Time (seconds):     0.000695496, Bandwidth (GB/s):     1.404124607
# Transfer size (Bytes):    2097152, Transfer Time (seconds):     0.001185074, Bandwidth (GB/s):     1.648103192
# Transfer size (Bytes):    4194304, Transfer Time (seconds):     0.002192402, Bandwidth (GB/s):     1.781721568
# Transfer size (Bytes):    8388608, Transfer Time (seconds):     0.004228194, Bandwidth (GB/s):     1.847715422
# Transfer size (Bytes):   16777216, Transfer Time (seconds):     0.010097656, Bandwidth (GB/s):     1.547388827
# Transfer size (Bytes):   33554432, Transfer Time (seconds):     0.018835837, Bandwidth (GB/s):     1.659071480
# Transfer size (Bytes):   67108864, Transfer Time (seconds):     0.041357043, Bandwidth (GB/s):     1.511229900
# Transfer size (Bytes):  134217728, Transfer Time (seconds):     0.080859221, Bandwidth (GB/s):     1.545896664
# Transfer size (Bytes):  268435456, Transfer Time (seconds):     0.164154610, Bandwidth (GB/s):     1.522954485
# Transfer size (Bytes):  536870912, Transfer Time (seconds):     0.331651945, Bandwidth (GB/s):     1.507604607
# Transfer size (Bytes): 1073741824, Transfer Time (seconds):     0.663716889, Bandwidth (GB/s):     1.506666498

# %% [markdown]
# ### CUDAWARE-MPI

# %% [markdown]
# Before looking at this code example, let us first describe [CUDAWARE-MPI](https://developer.nvidia.com/blog/introduction-cuda-aware-mpi/) and [GPUDirect RDMA](https://docs.nvidia.com/cuda/gpudirect-rdma/index.html). CUDAWARE-MPI is an MPI implementation that allows GPU buffers (e.g., GPU memory allocated with cudaMalloc) to be used directly in MPI calls. However, CUDAWARE-MPI alone does not specify whether data is stored in intermediate stages in CPU memory or passed from GPU to GPU. It will depend on the computational structure of the execution environment.
#
# The GPUDirect is an umbrella name used to refer to several specific technologies. In MPI, the GPUDirect technologies cover all kinds of inter-rank communication: intra-node, inter-node, and RDMA inter-node communication. Now let us take a look at the code below. It is the same as the tested version of MPI+CUDA, but now there are no calls to cudaMemcpy during the ping-pong steps. Instead, we use our GPU buffers (__d_A__) directly in MPI calls:

# %% [markdown]
# ```cpp
#     start_time = MPI_Wtime();
#     for(int i = 1; i <= loop_count; i++)
#     {
#       if(rank == 0)
#       {
#         MPI_Send(A, N, MPI_DOUBLE, 1, tag1, MPI_COMM_WORLD);
#         MPI_Recv(A, N, MPI_DOUBLE, 1, tag2, MPI_COMM_WORLD, &stat);
#       }else if(rank == 1)
#        {
#          MPI_Recv(A, N, MPI_DOUBLE, 0, tag1, MPI_COMM_WORLD, &stat);
#          MPI_Send(A, N, MPI_DOUBLE, 0, tag2, MPI_COMM_WORLD);
#        }
#     }
#     stop_time = MPI_Wtime();
# ```

# %%
# %%writefile ping-pong-CUDAWARE-MPI.cu
# #include <stdio.h>
# #include <stdlib.h>
# #include <cuda.h>
# #include <unistd.h>
# #include <mpi.h>
#
# int main(int argc, char *argv[])
# {
#     int size, rank;
#
#     MPI_Init(&argc, &argv);
#     MPI_Comm_size(MPI_COMM_WORLD, &size);
#     MPI_Comm_rank(MPI_COMM_WORLD, &rank);
#
#     MPI_Status status;
#
#     cudaSetDevice(rank);
#
#     double start_time, stop_time, elapsed_time;
#
#     for(int i = 0; i <= 27; i++)
#     {
#         long int N = 1 << i; /*Loop from 8 Bytes to 1 GB*/
#
#         double *A = (double*)calloc(N, sizeof(double)); /*Allocate memory for A on CPU*/
#
#         double *d_A;
#
#         cudaMalloc(&d_A, N * sizeof(double)) ;
#         cudaMemcpy(d_A, A, N * sizeof(double), cudaMemcpyHostToDevice);
#
#         int tag1 = 1000;
#         int tag2 = 2000;
#
#         int loop_count = 50;
#
#        /********************************/
#        /**/ start_time = MPI_Wtime();/**/
#        /********************************/
#
#         for(int i = 1; i <= loop_count; i++)
#         {
#             if(rank == 0)
#             {
#               MPI_Send(d_A, N, MPI_DOUBLE, 1, tag1, MPI_COMM_WORLD);
#               MPI_Recv(d_A, N, MPI_DOUBLE, 1, tag2, MPI_COMM_WORLD, &status);
#             }
#             else if(rank == 1)
#             {
#               MPI_Recv(d_A, N, MPI_DOUBLE, 0, tag1, MPI_COMM_WORLD, &status);
#               MPI_Send(d_A, N, MPI_DOUBLE, 0, tag2, MPI_COMM_WORLD);
#             }
#          }
#
#        /**********************************/
#        /**/  stop_time = MPI_Wtime(); /**/
#        /*********************************/
#
#         /*measured time*/
#         elapsed_time = stop_time - start_time;
#         long int num_B = 8 * N;
#         long int B_in_GB = 1 << 30;
#         double num_GB = (double)num_B / (double)B_in_GB;
#         double avg_time_per_transfer = elapsed_time / (2.0*(double)loop_count);
#
#         if(rank == 0)
#             printf("Transfer size (Bytes): %10li, Transfer Time (seconds): %15.9f, Bandwidth (GB/s): %15.9f\n",
#                     num_B, avg_time_per_transfer, num_GB/avg_time_per_transfer );
#
#         cudaFree(d_A);
#         free(A);
#     }
#
#     MPI_Finalize();
#
#     return 0;
# }
# Out:
# Writing ping-pong-CUDAWARE-MPI.cu

# %% [markdown]
# #### Run the Code

# %% [markdown]
# ##### Compile with Shell Script

# %%
# %%writefile howtocompile-CUDAWARE-MPI.sh
# #!/bin/bash
#
# usage()
# {
#  echo "howtocompile.sh: wrong number of input parameters. Exiting."
#  echo -e "Usage: bash howtocompile.sh <supercomputer>"
#  echo -e "  g.e: bash howtocompile.sh sdumont"
# }
#
#
# sdumont()
# {
#  nvcc $CPPFLAGS $LDFLAGS -lmpi ping-pong-CUDAWARE-MPI.cu -o ping-pong-CUDAWARE-MPI
# }
#
# #args in comand line
# if [ "$#" ==  0 ]; then
#  usage
#  exit
# fi
#
# #sdumont
# if [[ $1 == "sdumont" ]];then
#  sdumont
# fi
# Out:
# Writing howtocompile-CUDAWARE-MPI.sh

# %%
# !bash howtocompile-CUDAWARE-MPI.sh sdumont

# %% [markdown]
# ##### Execute with Shell Script

# %%
# %%writefile howtoexecute.sh
# #!/bin/bash
#
# usage()
# {
#  echo "howtoexecute.sh: wrong number of input parameters. Exiting."
#  echo -e "Usage: bash howtoexecute.sh <supercomputer>"
#  echo -e "  g.e: bash howtoexecute.sh sdumont"
# }
#
# sdumont()
# {
#  mpirun -np 2 --oversubscribe --report-bindings --map-by numa -x UCX_MEMTYPE_CACHE=n --map-by numa --report-bindings -mca pml ucx -mca btl ^vader,tcp,openib,smcuda ./ping-pong-CUDAWARE-MPI
# }
#
# #args in comand line
# if [ "$#" ==  0 ]; then
#  usage
#  exit
# fi
#
# #sdumont
# if [[ $1 == "sdumont" ]];then
#  sdumont
# fi
# Out:
# Writing howtoexecute.sh

# %%
# !bash howtoexecute.sh sdumont
# Out:
# [sdumont8046:56829] MCW rank 1 is not bound (or bound to all available processors)
# [sdumont8046:56828] MCW rank 0 is not bound (or bound to all available processors)
# Transfer size (Bytes):          8, Transfer Time (seconds):     0.000053376, Bandwidth (GB/s):     0.000139586
# Transfer size (Bytes):         16, Transfer Time (seconds):     0.000019042, Bandwidth (GB/s):     0.000782552
# Transfer size (Bytes):         32, Transfer Time (seconds):     0.000019208, Bandwidth (GB/s):     0.001551597
# Transfer size (Bytes):         64, Transfer Time (seconds):     0.000019305, Bandwidth (GB/s):     0.003087490
# Transfer size (Bytes):        128, Transfer Time (seconds):     0.000019385, Bandwidth (GB/s):     0.006149522
# Transfer size (Bytes):        256, Transfer Time (seconds):     0.000018911, Bandwidth (GB/s):     0.012607175
# Transfer size (Bytes):        512, Transfer Time (seconds):     0.000018728, Bandwidth (GB/s):     0.025460986
# Transfer size (Bytes):       1024, Transfer Time (seconds):     0.000019504, Bandwidth (GB/s):     0.048895819
# Transfer size (Bytes):       2048, Transfer Time (seconds):     0.000020980, Bandwidth (GB/s):     0.090913619
# Transfer size (Bytes):       4096, Transfer Time (seconds):     0.000024032, Bandwidth (GB/s):     0.158734734
# Transfer size (Bytes):       8192, Transfer Time (seconds):     0.000164125, Bandwidth (GB/s):     0.046485290
# Transfer size (Bytes):      16384, Transfer Time (seconds):     0.000068841, Bandwidth (GB/s):     0.221651702
# Transfer size (Bytes):      32768, Transfer Time (seconds):     0.000061718, Bandwidth (GB/s):     0.494464188
# Transfer size (Bytes):      65536, Transfer Time (seconds):     0.000074042, Bandwidth (GB/s):     0.824330543
# Transfer size (Bytes):     131072, Transfer Time (seconds):     0.000063993, Bandwidth (GB/s):     1.907554589
# Transfer size (Bytes):     262144, Transfer Time (seconds):     0.000066294, Bandwidth (GB/s):     3.682699532
# Transfer size (Bytes):     524288, Transfer Time (seconds):     0.000068309, Bandwidth (GB/s):     7.148116327
# Transfer size (Bytes):    1048576, Transfer Time (seconds):     0.000078973, Bandwidth (GB/s):    12.365783174
# Transfer size (Bytes):    2097152, Transfer Time (seconds):     0.000108563, Bandwidth (GB/s):    17.990694257
# Transfer size (Bytes):    4194304, Transfer Time (seconds):     0.000144727, Bandwidth (GB/s):    26.990469851
# Transfer size (Bytes):    8388608, Transfer Time (seconds):     0.000237830, Bandwidth (GB/s):    32.849135327
# Transfer size (Bytes):   16777216, Transfer Time (seconds):     0.000433155, Bandwidth (GB/s):    36.072535879
# Transfer size (Bytes):   33554432, Transfer Time (seconds):     0.000784961, Bandwidth (GB/s):    39.810870719
# Transfer size (Bytes):   67108864, Transfer Time (seconds):     0.001524684, Bandwidth (GB/s):    40.992095550
# Transfer size (Bytes):  134217728, Transfer Time (seconds):     0.002951899, Bandwidth (GB/s):    42.345617094
# Transfer size (Bytes):  268435456, Transfer Time (seconds):     0.005763008, Bandwidth (GB/s):    43.380121154
# Transfer size (Bytes):  536870912, Transfer Time (seconds):     0.011427729, Bandwidth (GB/s):    43.753225313
# Transfer size (Bytes): 1073741824, Transfer Time (seconds):     0.022708564, Bandwidth (GB/s):    44.036249975

# %% [markdown]
# ## Exercise 1: Comparison Performance internode: NCCL x CUDA-aware MPI

# %% [markdown]
# Compare the following ping-pong code using NCCL within one compute node with the previous implementation of CUDA-aware MPI. The idea is to understand why the values differ since both pass through the same high-speed channel inside the node.

# %%
# %%writefile ping-pong-NCCL.cu
# #include <iostream>
# #include <nccl.h>
# #include <cuda_runtime.h>
# #include <chrono>
#
# #define NUM_GPUS 2
#
# __global__ void print_values(int gpu_id, float *data) {
#   printf("GPU %d: %f\n", gpu_id, data[threadIdx.x]);
# }
#
# int main(int argc, char *argv[]) {
#   ncclComm_t comms[NUM_GPUS];
#
#   cudaStream_t streams[NUM_GPUS];
#
#   // Initializing NCCL
#   ncclUniqueId id;
#   ncclGetUniqueId(&id);
#   ncclGroupStart();
#   for (int i = 0; i < NUM_GPUS; ++i) {
#     cudaSetDevice(i);
#     ncclCommInitRank(&comms[i], NUM_GPUS, id, i);
#   }
#   ncclGroupEnd();
#
#   // Create a stream on each GPU
#   for (int i = 0; i < NUM_GPUS; ++i) {
#     cudaSetDevice(i);
#     cudaStreamCreate(&streams[i]);
#   }
#
#   for (int i = 0; i <= 27; i++) {
#     long int N = 1 << i;
#     size_t numBytes = N * sizeof(float);
#     float *buffers[NUM_GPUS];
#
#     // Allocate memory on each GPU
#     for (int j = 0; j < NUM_GPUS; ++j) {
#       cudaSetDevice(j);
#       cudaMalloc(&buffers[j], numBytes);
#     }
#
#     // Initializing data on each GPU
#     for (int j = 0; j < NUM_GPUS; ++j) {
#       cudaSetDevice(j);
#       float *h_data = new float[N];
#       for (int k = 0; k < N; ++k) h_data[k] = j + 1.0f;
#       cudaMemcpy(buffers[j], h_data, numBytes, cudaMemcpyHostToDevice);
#       delete[] h_data;
#     }
#
#     int loop_count = 50;
#
#     // Performing ping-pong between GPUs and measuring time
#     cudaEvent_t start, stop;
#     cudaSetDevice(0);
#     cudaEventCreate(&start);
#     cudaEventCreate(&stop);
#     cudaEventRecord(start, streams[0]);
#
#     for (int j = 0; j < loop_count; ++j) {
#       int src = j % NUM_GPUS;
#       int dst = (j + 1) % NUM_GPUS;
#
#       ncclGroupStart();
#       cudaSetDevice(src);
#       ncclSend(buffers[src], N, ncclFloat, dst, comms[src], streams[src]);
#
#       cudaSetDevice(dst);
#       ncclRecv(buffers[dst], N, ncclFloat, src, comms[dst], streams[dst]);
#       ncclGroupEnd();
#     }
#
#     cudaEventRecord(stop, streams[0]);
#     cudaEventSynchronize(stop);
#
#     float elapsedTime;
#     cudaEventElapsedTime(&elapsedTime, start, stop);
#
#     /*measured*/
#     long int num_B = 8 * N;
#     long int B_in_GB = 1 << 30;
#     double num_GB = (double)num_B / (double)B_in_GB;
#     double avg_time_per_transfer = (elapsedTime * 1e-3) / (2.0*(double)loop_count);
#     float bandwidth = num_GB/avg_time_per_transfer ;
#
#     printf("Transfer size (Bytes): %10li, Transfer Time (seconds): %15.9f, Bandwidth (GB/s): %15.9f\n",
#                   num_B, avg_time_per_transfer, bandwidth  );
#
#     // Cleanup memory
#     for (int j = 0; j < NUM_GPUS; ++j) {
#       cudaSetDevice(j);
#       cudaFree(buffers[j]);
#     }
#   }
#
#   // Destroy NCCL communicators
#   for (int i = 0; i < NUM_GPUS; ++i)
#   {
#     cudaSetDevice(i);
#     ncclCommDestroy(comms[i]);
#   }
#
#   return 0;
# }
# Out:
# Writing ping-pong-NCCL.cu

# %% [markdown]
# ### Compile and Run the Code

# %% [markdown]
# ##### Compile with Shell Script

# %%
# %%writefile howtocompile.sh
# #!/bin/bash
#
# usage()
# {
#  echo "howtocompile.sh: wrong number of input parameters. Exiting."
#  echo -e "Usage: bash howtocompile.sh <supercomputer>"
#  echo -e "  g.e: bash howtocompile.sh sdumont"
# }
#
#
# sdumont()
# {
#  nvcc $CPPFLAGS $LDFLAGS ping-pong-NCCL.cu -o ping-pong-NCCL -lnccl -std=c++11
# }
#
# #args in comand line
# if [ "$#" ==  0 ]; then
#  usage
#  exit
# fi
#
# #sdumont
# if [[ $1 == "sdumont" ]];then
#  sdumont
# fi
# Out:
# Overwriting howtocompile.sh

# %%
# !bash howtocompile.sh sdumont

# %% [markdown]
# ##### Execute with Shell Script

# %%
# %%writefile howtoexecute.sh
# #!/bin/bash
#
# usage()
# {
#  echo "howtoexecute.sh: wrong number of input parameters. Exiting."
#  echo -e "Usage: bash howtoexecute.sh <supercomputer>"
#  echo -e "  g.e: bash howtoexecute.sh sdumont"
# }
#
# sdumont()
# {
#  ./ping-pong-NCCL
# }
#
# #args in comand line
# if [ "$#" ==  0 ]; then
#  usage
#  exit
# fi
#
# #sdumont
# if [[ $1 == "sdumont" ]];then
#  sdumont
# fi
# Out:
# Overwriting howtoexecute.sh

# %%
# !bash howtoexecute.sh sdumont
# Out:
# Transfer size (Bytes):          8, Transfer Time (seconds):     0.000071967, Bandwidth (GB/s):     0.000103528
# Transfer size (Bytes):         16, Transfer Time (seconds):     0.000006124, Bandwidth (GB/s):     0.002433431
# Transfer size (Bytes):         32, Transfer Time (seconds):     0.000006011, Bandwidth (GB/s):     0.004958063
# Transfer size (Bytes):         64, Transfer Time (seconds):     0.000005990, Bandwidth (GB/s):     0.009950028
# Transfer size (Bytes):        128, Transfer Time (seconds):     0.000006001, Bandwidth (GB/s):     0.019866096
# Transfer size (Bytes):        256, Transfer Time (seconds):     0.000006031, Bandwidth (GB/s):     0.039529819
# Transfer size (Bytes):        512, Transfer Time (seconds):     0.000006021, Bandwidth (GB/s):     0.079194099
# Transfer size (Bytes):       1024, Transfer Time (seconds):     0.000006021, Bandwidth (GB/s):     0.158388197
# Transfer size (Bytes):       2048, Transfer Time (seconds):     0.000006042, Bandwidth (GB/s):     0.315702558
# Transfer size (Bytes):       4096, Transfer Time (seconds):     0.000006052, Bandwidth (GB/s):     0.630336761
# Transfer size (Bytes):       8192, Transfer Time (seconds):     0.000006062, Bandwidth (GB/s):     1.258543968
# Transfer size (Bytes):      16384, Transfer Time (seconds):     0.000006083, Bandwidth (GB/s):     2.508481026
# Transfer size (Bytes):      32768, Transfer Time (seconds):     0.000006257, Bandwidth (GB/s):     4.877630711
# Transfer size (Bytes):      65536, Transfer Time (seconds):     0.000006676, Bandwidth (GB/s):     9.141816139
# Transfer size (Bytes):     131072, Transfer Time (seconds):     0.000007342, Bandwidth (GB/s):    16.626121521
# Transfer size (Bytes):     262144, Transfer Time (seconds):     0.000008858, Bandwidth (GB/s):    27.562841415
# Transfer size (Bytes):     524288, Transfer Time (seconds):     0.000010455, Bandwidth (GB/s):    46.702953339
# Transfer size (Bytes):    1048576, Transfer Time (seconds):     0.000013609, Bandwidth (GB/s):    71.758789062
# Transfer size (Bytes):    2097152, Transfer Time (seconds):     0.000019784, Bandwidth (GB/s):    98.724044800
# Transfer size (Bytes):    4194304, Transfer Time (seconds):     0.000031171, Bandwidth (GB/s):   125.318572998
# Transfer size (Bytes):    8388608, Transfer Time (seconds):     0.000053914, Bandwidth (GB/s):   144.907791138
# Transfer size (Bytes):   16777216, Transfer Time (seconds):     0.000103721, Bandwidth (GB/s):   150.644577026
# Transfer size (Bytes):   33554432, Transfer Time (seconds):     0.000195604, Bandwidth (GB/s):   159.761169434
# Transfer size (Bytes):   67108864, Transfer Time (seconds):     0.000377580, Bandwidth (GB/s):   165.528045654
# Transfer size (Bytes):  134217728, Transfer Time (seconds):     0.000735314, Bandwidth (GB/s):   169.995422363
# Transfer size (Bytes):  268435456, Transfer Time (seconds):     0.001461944, Bandwidth (GB/s):   171.005157471
# Transfer size (Bytes):  536870912, Transfer Time (seconds):     0.002915154, Bandwidth (GB/s):   171.517532349
# Transfer size (Bytes): 1073741824, Transfer Time (seconds):     0.005820764, Bandwidth (GB/s):   171.798751831

# %% [markdown]
# ## Clear the Memory

# %% [markdown]
# Before moving on, please execute the following cell to clear up the CPU memory. This is required to move on to the next notebook.

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)

# %% [markdown]
# ## Next

# %% [markdown]
# Please continue to the next notebook: [_4-SDumont-MCπ-SGPU.ipynb_](4-SDumont-MCπ-SGPU.ipynb).
